# %%
# !pip install -q num2words

# %%
from datasets import load_dataset

drive_lm = load_dataset("MehdiJmlkh/DriveLM")
nuscenes = load_dataset("MehdiJmlkh/nuscenes")

# %%
import json
from datasets import Dataset


class DriveLM:
    def __init__(self, drive_lm, nuscenes):
        self.drive_lm = drive_lm
        self.nuscenes = nuscenes

    def __getitem__(self, idx):
      sample = self.drive_lm[idx]
      nuscenes_index = sample["nuscenes_index"]
      sample['images'] = self.nuscenes[nuscenes_index]

      return sample

    def __len__(self):
        return len(self.drive_lm)

dataset = {
    "train": DriveLM(drive_lm["train"].select(range(1000)), nuscenes["train"]),
    "test": DriveLM(drive_lm["test"], nuscenes["test"])
}

# %%
import torch
from transformers import AutoProcessor, AutoModelForImageTextToText
from PIL import Image
import num2words
import torch
import torch.nn as nn
from transformers import ViTModel, AutoImageProcessor
from transformers.modeling_outputs import BaseModelOutput
import matplotlib.pyplot as plt
import numpy as np
from functools import partial
from torchvision.transforms import functional as F_transforms
from huggingface_hub import PyTorchModelHubMixin

# %% [markdown]
# # Load Dataset and Model

# %%
model_path = "HuggingFaceTB/SmolVLM2-2.2B-Instruct"

processor = AutoProcessor.from_pretrained(model_path)
model = AutoModelForImageTextToText.from_pretrained(
    model_path,
    torch_dtype=torch.bfloat16,
    device_map="cuda",
)

processor.image_processor.max_image_size["longest_edge"]= 384
processor.image_processor.do_image_splitting=False
processor.image_processor.do_resize=True

for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# # Fine-tune

# %%
def display_output(inputs, outputs, loss, global_step):
    logits = outputs.logits  # (batch, seq_len, vocab_size)
    pred_ids = torch.argmax(logits, dim=-1)  # (batch, seq_len)

    labels = inputs["labels"].clone()

    mask = labels != -100
    pred_ids_filtered = [p[m].tolist() for p, m in zip(pred_ids, mask)]
    label_ids_filtered = [l[m].tolist() for l, m in zip(labels, mask)]

    pred_text = processor.tokenizer.batch_decode(pred_ids_filtered, skip_special_tokens=True)
    label_text = processor.tokenizer.batch_decode(label_ids_filtered, skip_special_tokens=True)

    print(f"Step: {global_step}, Loss: {loss: .4}")
    print("Prediction:", pred_text[0])
    print("Target:", label_text[0], end='', sep='')
    print("-" * 50)

# %%
epochs = 1
batch_size = 1
learning_rate = 2e-5
save_steps = 10
logging_steps = 10

# %%
from transformers import Trainer
from transformers.trainer import _is_peft_model
from transformers.models.auto.modeling_auto import MODEL_FOR_CAUSAL_LM_MAPPING_NAMES

class OutputDisplayTrainer(Trainer):
    global_step = 1
    logging_steps = logging_steps
    def compute_loss(
        self,
        model: nn.Module,
        inputs,
        return_outputs: bool = False,
        num_items_in_batch= None,
    ):

        if (self.label_smoother is not None or self.compute_loss_func is not None) and "labels" in inputs:
            labels = inputs.pop("labels")
        else:
            labels = None
        if self.model_accepts_loss_kwargs:
            kwargs = {}
            if num_items_in_batch is not None:
                kwargs["num_items_in_batch"] = num_items_in_batch
            inputs = {**inputs, **kwargs}
        outputs = model(**inputs)

        if self.args.past_index >= 0:
            self._past = outputs[self.args.past_index]

        if labels is not None:
            unwrapped_model = self.accelerator.unwrap_model(model)
            if _is_peft_model(unwrapped_model):
                model_name = unwrapped_model.base_model.model._get_name()
            else:
                model_name = unwrapped_model._get_name()

            if self.compute_loss_func is not None:
                loss = self.compute_loss_func(outputs, labels, num_items_in_batch=num_items_in_batch)
            elif model_name in MODEL_FOR_CAUSAL_LM_MAPPING_NAMES.values():
                loss = self.label_smoother(outputs, labels, shift_labels=True)
            else:
                loss = self.label_smoother(outputs, labels)
        else:
            if isinstance(outputs, dict) and "loss" not in outputs:
                raise ValueError(
                    "The model did not return a loss from the inputs, only the following keys: "
                    f"{','.join(outputs.keys())}. For reference, the inputs it received are {','.join(inputs.keys())}."
                )

            loss = outputs["loss"] if isinstance(outputs, dict) else outputs[0]

        if (
            self.args.average_tokens_across_devices
            and (self.model_accepts_loss_kwargs or self.compute_loss_func)
            and num_items_in_batch is not None
        ):
            loss *= self.accelerator.num_processes

        if OutputDisplayTrainer.global_step % OutputDisplayTrainer.logging_steps == 0:
            display_output(inputs, outputs, loss, OutputDisplayTrainer.global_step)
        OutputDisplayTrainer.global_step += 1

        return (loss, outputs) if return_outputs else loss

# %%
import torch
import gc

torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
from peft import LoraConfig, get_peft_model
from transformers import Trainer, TrainingArguments
from peft import PeftModel

peft_config = LoraConfig(
    r=16,
    lora_alpha=16,
    target_modules="all-linear",
    lora_dropout=0.05,
    task_type="CAUSAL_LM",
)

peft_model = get_peft_model(model, peft_config)

# peft_model = PeftModel.from_pretrained(model, "MehdiJmlkh/SmolDriver-Peft", is_trainable=True)

for param in peft_model.model.model.vision_model.parameters():
    param.requires_grad = True

# %%
from torch.utils.data import Dataset

class VLMQADataset(Dataset):
    def __init__(self, dataset: DriveLM, is_train=True):
        self.dataset = dataset
        self.is_train = is_train

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]

        user_msg = []
        cameras = ['CAM_FRONT_LEFT', 'CAM_FRONT', 'CAM_FRONT_RIGHT', 'CAM_BACK_LEFT', 'CAM_BACK', 'CAM_BACK_RIGHT']
        for camera in cameras:
            user_msg.extend([
                {"type": "text", "text": camera},
                {"type": "image", "image": item["images"][camera]}
            ])

        user_msg.append({
            "type": "text",
            "text":f"Scene description:{item['scene_description']} Question: {item['question']}"
        })

        assistant_msg = [{"type": "text", "text": item["answer"]}]

        if not self.is_train:
            conversation = [
                {
                    "role": "user",
                    "content": user_msg
                }
            ]
            return self.__apply_chat_template(conversation, True)


        conversation = [
            {
                "role": "user",
                "content": user_msg
            },
            {
                "role": "assistant",
                "content": assistant_msg
            }
        ]
        inputs = self.__apply_chat_template(conversation)

        label_start_idx = self.__get_label_start_idx(inputs)

        labels = inputs['input_ids'].clone()
        labels[:, :label_start_idx] = -100
        inputs['labels'] = labels

        return inputs

    def __apply_chat_template(self, conversation, add_generation_prompt=False):
        return processor.apply_chat_template(
            conversation,
            add_generation_prompt=add_generation_prompt,
            tokenize=True,
            return_dict=True,
            return_tensors="pt"
        )

    def __get_label_start_idx(self, inputs):
        utterance_id = processor.tokenizer.convert_tokens_to_ids('<end_of_utterance>')
        utterance_idx = inputs['input_ids'][0].tolist().index(utterance_id)
        num_assistant_ids = 4
        label_idx = utterance_idx + num_assistant_ids + 1

        return label_idx

# %%
from transformers import Trainer, TrainingArguments

train_dataset = VLMQADataset(dataset["train"])

training_args = TrainingArguments(
    output_dir="./fine-tune-checkpoints",
    per_device_train_batch_size=batch_size,
    num_train_epochs=epochs,
    learning_rate=learning_rate,
    logging_steps=logging_steps,
    bf16=True,
    report_to="none",
    label_names=["labels"],
    gradient_checkpointing=True,
    save_total_limit=2,
    # save_strategy="steps",
    # save_steps=save_steps,
    seed=42,
    data_seed=42,
)


def pad_labels(labels):
    pad_token_label_id = -100
    max_len = max(len(label) for label in labels)

    padded_labels = torch.stack([
        torch.cat([torch.full((max_len - len(label),), pad_token_label_id), label])
        for label in labels
    ])

    return padded_labels


def data_collator(features):
    # return features[0]

    features_flatten = []
    labels = []
    pixel_values = []
    for feature in features:
        labels.append(feature['labels'].flatten())
        pixel_values.append(feature['pixel_values'])
        del feature['labels']
        del feature['pixel_values']

        for key, item in feature.items():
            feature[key] = item[0]
        features_flatten.append(feature)

    batch = processor.tokenizer.pad(features_flatten, padding=True, return_tensors="pt")
    batch['labels'] = pad_labels(labels)
    batch['pixel_values'] = torch.concatenate(pixel_values)

    return batch

trainer = OutputDisplayTrainer(
    model=peft_model,
    args=training_args,
    train_dataset=train_dataset,
    data_collator=data_collator,
)

trainer.train()
# Out:
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='1001' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1000 3:18:57, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.692700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.094400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.492100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.041300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.503100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.593100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.818100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.054900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.951900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.387900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.748500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.858200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.049200</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.117800</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.929600</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.039500</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.657200</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.570400</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.832200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.661700</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.906800</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.785600</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.461000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.959200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.648800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.034700</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.536200</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.470400</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.622900</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.906900</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.527400</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.594000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.132700</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.670200</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.427000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.532500</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.392100</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.614100</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.511900</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.080600</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.480000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.753700</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.618100</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.204000</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.369500</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.577700</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.392700</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.704400</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.378400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.257900</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.588800</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.515400</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.454400</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.876100</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.413900</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.324700</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.763400</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.439400</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.440600</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.389400</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.305900</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.552100</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.475200</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.675100</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.627800</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.789800</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.283700</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.531500</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.498700</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.193100</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.338700</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.763500</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.653200</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.637900</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.633800</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.615100</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.263700</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.623200</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.353000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.352700</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.362600</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.560400</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.864400</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.572900</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.640900</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.633300</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.240800</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.768700</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.621300</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.421500</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.223800</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.399800</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.358800</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.464500</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.474900</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.442600</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.998200</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.596700</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.460300</td>
#     </tr>
#   </tbody>
# </table><p>
# Step: 10, Loss:  2.063
# Prediction:  cars are stopped forward
# R
# Target: Three cars are moving.
# --------------------------------------------------
# Step: 20, Loss:  0.8093
# Prediction: ,
# R
# Target: No.
# --------------------------------------------------
# Step: 30, Loss:  2.251
# Prediction:  are a vehicle vehicle, the of the ego vehicle, There
# Ass
# Target: There is one moving car in front of the ego car.
# --------------------------------------------------
# Step: 40, Loss:  0.2881
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 50, Loss:  0.6013
# Prediction:  pedestrian is the front right of the ego car is standing.
# Ass
# Target: The pedestrian to the front right of the ego car is moving.
# --------------------------------------------------
# Step: 60, Loss:  2.096
# Prediction:  ego vehicle will likely to. answer vehicle is going going.
# Ass
# Target: The ego vehicle is going straight. The ego vehicle is not moving.
# --------------------------------------------------
# Step: 70, Loss:  0.7091
# Prediction:  truck is front of the ego car is stopped.
# Ass
# Target: The truck in front of the ego car is parked.
# --------------------------------------------------
# Step: 80, Loss:  0.9999
# Prediction:  trucks are parked.
# Ass
# Target: Two trucks are moving.
# --------------------------------------------------
# Step: 90, Loss:  1.009
# Prediction:  are traffic traffic in front of the ego car.
# Ass
# Target: There are three barriers in front of the ego car.
# --------------------------------------------------
# Step: 100, Loss:  1.279
# Prediction:  are barriers cars and cars of, and people, and a person light. the back left of the ego car.
# Ass
# Target: There are many trucks, one car, two barriers, and one traffic cone to the back left of the ego car.
# --------------------------------------------------
# Step: 110, Loss:  0.0009949
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 120, Loss:  1.558
# Prediction:  trucks are parked. and one are moving.
# Ass
# Target: Many trucks are parked, and two are moving.
# --------------------------------------------------
# Step: 130, Loss:  0.625
# Prediction:  car is moving.
# Question
# Target: One car is moving.
# --------------------------------------------------
# Step: 140, Loss:  0.901
# Prediction:  are a person, one vehicles. the front right of the ego car.
# Question
# Target: There is one pedestrian and many cars to the front right of the ego car.
# --------------------------------------------------
# Step: 150, Loss:  2.274
# Prediction:  ego vehicle will likely to the right. ego vehicle is stopping straight a speed.
# Scene
# Target: The ego vehicle is steering to the right. The ego vehicle is driving with normal speed.
# --------------------------------------------------
# Step: 160, Loss:  0.00485
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 170, Loss:  0.5949
# Prediction:  car is parked.
# Question
# Target: One car is moving.
# --------------------------------------------------
# Step: 180, Loss:  0.001296
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 190, Loss:  1.773
# Prediction: . the droplets on the glass will affect the driver's line of sight. down and approaching road is wet. wet days.
# Ass
# Target: Yes, water droplets on the glass can affect the driver's line of sight. Slow down when the road is slippery on rainy days.
# --------------------------------------------------
# Step: 200, Loss:  1.899
# Prediction:  the straight a same speed, follow right.
# Ass
# Target: Keep going at the same speed and turn left.
# --------------------------------------------------
# Step: 210, Loss:  0.002221
# Prediction: .
# Question
# Target: Yes.
# --------------------------------------------------
# Step: 220, Loss:  1.036
# Prediction: .
# Question
# Target: No.
# --------------------------------------------------
# Step: 230, Loss:  0.2334
# Prediction:  light.
# Question
# Target: Red light.
# --------------------------------------------------
# Step: 240, Loss:  1.36
# Prediction:  pedestrians are standing.
# Question
# Target: Many pedestrians are moving.
# --------------------------------------------------
# Step: 250, Loss:  0.265
# Prediction:  car is moving.
# Ass
# Target: One car is moving.
# --------------------------------------------------
# Step: 260, Loss:  0.6509
# Prediction:  construction vehicle is the front right of the ego car is not.
#
#
# Target: The construction vehicle to the front right of the ego car is moving.
# --------------------------------------------------
# Step: 270, Loss:  0.2979
# Prediction:  pedestrian is standing.
# Question
# Target: One pedestrian is standing.
# --------------------------------------------------
# Step: 280, Loss:  0.6976
# Prediction:  pedestrian the pedestrians is walking, and one is standing still
# Question
# Target: One of the pedestrians is moving, and one is standing.
# --------------------------------------------------
# Step: 290, Loss:  1.685
# Prediction: erate, brake straight. brake right, and go lanes the right..
# Question
# Target: Accelerate and go ahead, turn left, and change to the left lane.
# --------------------------------------------------
# Step: 300, Loss:  5.504e-05
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 310, Loss:  1.108
# Prediction: erate, turn straight. brake right, and go right.
# Question
# Target: Accelerate and go ahead, turn left, and turn right.
# --------------------------------------------------
# Step: 320, Loss:  0.536
# Prediction:  are two cars and one trucks to the back right of the ego car.
# Ass
# Target: There are three cars and two motorcycles to the back right of the ego car.
# --------------------------------------------------
# Step: 330, Loss:  2.003
# Prediction:  are a to particular. comment attention to. this scene. it ego is empty empty.
#
# Target: There is nothing in particular to pay attention to in this scene; the road is quite empty.
# --------------------------------------------------
# Step: 340, Loss:  1.302
# Prediction:  motorcycle is parked a rider.
#
#
# Target: One motorcycle is without a rider.
# --------------------------------------------------
# Step: 350, Loss:  0.4133
# Prediction:  pedestrian is the front left of the ego car is moving.
#
#
# Target: The pedestrian to the front left of the ego car is moving.
# --------------------------------------------------
# Step: 360, Loss:  0.8618
# Prediction:  are many cars, one truck, one one pedestrians to the ego car.
# Ass
# Target: There are two cars, one motorcycle, and two trucks behind the ego car.
# --------------------------------------------------
# Step: 370, Loss:  0.005277
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 380, Loss:  1.231
# Prediction:  is  traffic elements: the front view: One first is the elements elements is as1 light, moving, 00..0,, 19..64, 10..84, 451.71), (ped sign, one straight, 6.0, 09..42, 600.19, 670.52), (traffic sign, turn right, 0.0, 657.17, 129.68, 684.39)].
# Ass
# Target: There are three traffic elements in the front view. The information of these traffic elements is [(traffic light, red, 696.74, 446.79, 704.77, 460.35), (road sign, go straight, 0.0, 657.17, 129.68, 684.39), (road sign, turn left, 0.0, 657.17, 129.68, 684.39)].
# --------------------------------------------------
# Step: 390, Loss:  0.4729
# Prediction:  are two cars to cars cars to the front left of the ego car.
# Question
# Target: There are many pedestrians and two cars to the front left of the ego car.
# --------------------------------------------------
# Step: 400, Loss:  3.121
# Prediction:  on on the wind. affect driving.
# Ass
# Target: Water droplets on the glass will affect visibility.
# --------------------------------------------------
# Step: 410, Loss:  0.1952
# Prediction:  are two pedestrians to the back right of the ego car.
# Question
# Target: There are two pedestrians to the back right of the ego car.
# --------------------------------------------------
# Step: 420, Loss:  0.9288
# Prediction:  are two cars to cars cars, and cars, and one trucks to the ego car.
#
#
# Target: There are many pedestrians, three bicycles, three cars, and two trucks behind the ego car.
# --------------------------------------------------
# Step: 430, Loss:  0.8621
# Prediction:  are one truck cone and one cars, and one truck to the front right of the ego car.
# Ass
# Target: There is one traffic cone, three cars, and one trailer to the front right of the ego car.
# --------------------------------------------------
# Step: 440, Loss:  0.0001528
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 450, Loss:  0.5045
# Prediction: .
# Question
# Target: No.
# --------------------------------------------------
# Step: 460, Loss:  0.9427
# Prediction: erate, go straight, go brake right.
# Question
# Target: Accelerate and go ahead, and turn right.
# --------------------------------------------------
# Step: 470, Loss:  0.4857
# Prediction:  cars are moving.
#
#
# Target: Many cars are parked.
# --------------------------------------------------
# Step: 480, Loss:  5.477e-05
# Prediction: .
#
#
# Target: Yes.
# --------------------------------------------------
# Step: 490, Loss:  0.006756
# Prediction: .
#
#
# Target: No.
# --------------------------------------------------
# Step: 500, Loss:  0.5629
# Prediction:  of the cars are moving, and one are moving.
#
#
# Target: Two of the cars are parked, and two are moving.
# --------------------------------------------------
# Step: 510, Loss:  0.9581
# Prediction: ..
# Question
# Target: Green light.
# --------------------------------------------------
# Step: 520, Loss:  1.997e-05
# Prediction: .
# Question
# Target: Yes.
# --------------------------------------------------
# Step: 530, Loss:  0.7566
# Prediction:  are two car, one cars, and one traffic to the back right of the ego car.
# Ass
# Target: There are one pedestrian, two cars, and one barrier to the back right of the ego car.
# --------------------------------------------------
# Step: 540, Loss:  0.0003501
# Prediction: .
#
#
# Target: No.
# --------------------------------------------------
# Step: 550, Loss:  0.001586
# Prediction: .
#
#
# Target: Yes.
# --------------------------------------------------
# Step: 560, Loss:  2.402e-05
# Prediction: .
#
#
# Target: Yes.
# --------------------------------------------------
# Step: 570, Loss:  0.00358
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 580, Loss:  0.7722
# Prediction:  motorcycle is parked a rider.
#
#
# Target: One motorcycle is without a rider.
# --------------------------------------------------
# Step: 590, Loss:  0.5438
# Prediction:  are many barriers to one traffic, and traffic cones, and car, one one truck to the back left of the ego car.
# Ass
# Target: There are many pedestrians, two barriers, two traffic cones, one car, and one truck to the back left of the ego car.
# --------------------------------------------------
# Step: 600, Loss:  0.0001079
# Prediction: .
#
#
# Target: Yes.
# --------------------------------------------------
# Step: 610, Loss:  0.704
# Prediction:  pedestrians are standing. and one is standing.
#
#
# Target: Many pedestrians are moving, and one is standing.
# --------------------------------------------------
# Step: 620, Loss:  2.855e-05
# Prediction: .
# Question
# Target: Yes.
# --------------------------------------------------
# Step: 630, Loss:  3.847e-05
# Prediction: .
#
#
# Target: Yes.
# --------------------------------------------------
# Step: 640, Loss:  0.1865
# Prediction:  of the trucks is moving, and one is parked.
#
#
# Target: One of the trucks is moving, and one is parked.
# --------------------------------------------------
# Step: 650, Loss:  1.672
# Prediction:  right in going speedingting the right, and slightly lanes the right lane. dangerous actions to the ego vehicle. this scenario.
# Ass
# Target: Turning right, slightly offset to the right, and changing to the right lane are dangerous actions for the ego vehicle in this scenario.
# --------------------------------------------------
# Step: 660, Loss:  0.5737
# Prediction:  pedestrians are moving. and one are standing.
#
#
# Target: Many pedestrians are moving, and two are standing.
# --------------------------------------------------
# Step: 670, Loss:  0.007504
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 680, Loss:  0.1031
# Prediction:  cars are parked.
#
#
# Target: Many cars are parked.
# --------------------------------------------------
# Step: 690, Loss:  0.003627
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 700, Loss:  0.3016
# Prediction:  trailer is the front left of the ego car is parked.
#
#
# Target: The trailer to the front left of the ego car is parked.
# --------------------------------------------------
# Step: 710, Loss:  0.0006435
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 720, Loss:  1.354
# Prediction:  are  traffic elements in the front view. The status is each traffic elements is as1 light, moving, 000.0,, 10..81, 150.8,, 211.01), (traffic light, unknown, 10..09, 281.08, 310.03, 211.16), (traffic light, unknown, 10..81, 107.14, 744.51, 346.49), (traffic light, red, 702.42, 256.72, 875.79 200.63), (traffic light, red, 821.7, 205.0,, 383.1,, 300.19),
# Ass
# Target: There are many traffic elements in the front view. The information of these traffic elements is [(traffic light, unknown, 158.81, 207.08, 188.41, 267.63), (traffic light, unknown, 320.87, 197.09, 349.75, 258.41), (traffic light, green, 722.29, 256.69, 742.39, 300.29), (traffic light, green, 855.73, 262.25, 876.6, 307.73), (traffic light, unknown, 365.1, 367.54, 380.95, 400.24)].
# --------------------------------------------------
# Step: 730, Loss:  0.09251
# Prediction:  trucks are moving.
#
#
# Target: Two trucks are moving.
# --------------------------------------------------
# Step: 740, Loss:  8.135e-05
# Prediction: .
# Question
# Target: Yes.
# --------------------------------------------------
# Step: 750, Loss:  0.2634
# Prediction:  trailer is the front right of the ego car is parked.
#
#
# Target: The trailer to the front right of the ego car is parked.
# --------------------------------------------------
# Step: 760, Loss:  1.208
# Prediction:  ego vehicle will going ahead to the right. The ego vehicle is moving slowly.
#
#
# Target: The ego vehicle is slightly steering to the right. The ego vehicle is driving slowly.
# --------------------------------------------------
# Step: 770, Loss:  0.000454
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 780, Loss:  0.9322
# Prediction:  bicycle the bicycles is a rider, one is not. a rider.
#
#
# Target: One of the bicycles has a rider and one does not have a rider.
# --------------------------------------------------
# Step: 790, Loss:  0.000586
# Prediction: .
#
#
# Target: Yes.
# --------------------------------------------------
# Step: 800, Loss:  0.09105
# Prediction:  straight.
# Question
# Target: Go straight.
# --------------------------------------------------
# Step: 810, Loss:  0.214
# Prediction:  pedestrians are moving.
#
#
# Target: Many pedestrians are moving.
# --------------------------------------------------
# Step: 820, Loss:  0.0004001
# Prediction: .
# Question
# Target: Yes.
# --------------------------------------------------
# Step: 830, Loss:  0.1541
# Prediction:  pedestrians are moving,
#
#
# Target: Many pedestrians are moving.
# --------------------------------------------------
# Step: 840, Loss:  4.264e-05
# Prediction: .
#
#
# Target: Yes.
# --------------------------------------------------
# Step: 850, Loss:  1.579
# Prediction: ke gently, come stop, turn ahead to the right,
# Ass
# Target: Brake gently to a stop, slightly offset to the right.
# --------------------------------------------------
# Step: 860, Loss:  0.4974
# Prediction:  ego vehicle will going straight. ego vehicle is not moving.
#
# Target: The ego vehicle is going straight. The ego vehicle is not moving.
# --------------------------------------------------
# Step: 870, Loss:  0.0002789
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 880, Loss:  0.4091
# Prediction:  pedestrians are moving. and one is standing.
#
#
# Target: Many pedestrians are moving, and one is standing.
# --------------------------------------------------
# Step: 890, Loss:  0.6985
# Prediction:  are many pedestrians to one car, two car, two cars, and one trucks in front of the ego car.
# Ass
# Target: There are many pedestrians, one trailer, one motorcycle, three cars, and two trucks in front of the ego car.
# --------------------------------------------------
# Step: 900, Loss:  0.0006408
# Prediction: .
#
#
# Target: Yes.
# --------------------------------------------------
# Step: 910, Loss:  0.8737
# Prediction:  are many pedestrians vehicles, front of the ego car, and moving car on front of the ego car, and moving truck behind the ego car, one one moving car behind the ego car. There
#
#
# Target: There are three moving cars in front of the ego car, one parked car in front of the ego car, one parked car behind the ego car, and one moving truck behind the ego car.
# --------------------------------------------------
# Step: 920, Loss:  1.688
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
# Step: 930, Loss:  0.09178
# Prediction:  car is moving.
#
#
# Target: One car is moving.
# --------------------------------------------------
# Step: 940, Loss:  0.1506
# Prediction:  truck is parked.
#
#
# Target: One truck is moving.
# --------------------------------------------------
# Step: 950, Loss:  0.000693
# Prediction: .
#
#
# Target: No.
# --------------------------------------------------
# Step: 960, Loss:  0.1125
# Prediction: , there are many elements in the front view.
#
#
# Target: Yes, there are traffic elements in the front view.
# --------------------------------------------------
# Step: 970, Loss:  1.75
# Prediction: .
#
# Target: No.
# --------------------------------------------------
# Step: 980, Loss:  0.0001347
# Prediction: .
#
# Target: Yes.
# --------------------------------------------------
# Step: 990, Loss:  0.4966
# Prediction:  cars the cars are parked, and two is moving.
#
#
# Target: Three of the cars are parked, and one is moving.
# --------------------------------------------------
# Step: 1000, Loss:  0.1189
# Prediction: .
# Ass
# Target: Yes.
# --------------------------------------------------
#     <div>
#
#       <progress value='1000' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1000 3:19:20, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.692700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.094400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.492100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.041300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.503100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.593100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.818100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.054900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.951900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.387900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.748500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.858200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.049200</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.117800</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.929600</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.039500</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.657200</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.570400</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.832200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.661700</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.906800</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.785600</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.461000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.959200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.648800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.034700</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.536200</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.470400</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.622900</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.906900</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.527400</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.594000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.132700</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.670200</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.427000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.532500</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.392100</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.614100</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.511900</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.080600</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.480000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.753700</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.618100</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.204000</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.369500</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.577700</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.392700</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.704400</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.378400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.257900</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.588800</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.515400</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.454400</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.876100</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.413900</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.324700</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.763400</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.439400</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.440600</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.389400</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.305900</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.552100</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.475200</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.675100</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.627800</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.789800</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.283700</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.531500</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.498700</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.193100</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.338700</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.763500</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.653200</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.637900</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.633800</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.615100</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.263700</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.623200</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.353000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.352700</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.362600</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.560400</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.864400</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.572900</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.640900</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.633300</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.240800</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.768700</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.621300</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.421500</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.223800</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.399800</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.358800</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.464500</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.474900</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.442600</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.998200</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.596700</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.460300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.686400</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1000, training_loss=0.6481156706809997, metrics={'train_runtime': 11973.8437, 'train_samples_per_second': 0.084, 'train_steps_per_second': 0.084, 'total_flos': 7762815968537760.0, 'train_loss': 0.6481156706809997, 'epoch': 1.0})

# %% [markdown]
# # save and load

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
peft_model.push_to_hub("ArianFiroozi/SmolVLM-Peft")
# Out:
# adapter_model.safetensors:   0%|          | 0.00/108M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ArianFiroozi/SmolVLM-Peft/commit/ffb92286c93cd79ac5b5e37183be278f99fbfbb1', commit_message='Upload model', commit_description='', oid='ffb92286c93cd79ac5b5e37183be278f99fbfbb1', pr_url=None, repo_url=RepoUrl('https://huggingface.co/ArianFiroozi/SmolVLM-Peft', endpoint='https://huggingface.co', repo_type='model', repo_id='ArianFiroozi/SmolVLM-Peft'), pr_revision=None, pr_num=None)

# %%
from peft import PeftModel


peft_model = PeftModel.from_pretrained(model, "ArianFiroozi/SmolVLM-Peft", is_trainable=False)

# for param in peft_model.model.model.vision_model.parameters():
#     param.requires_grad = True

# %% [markdown]
# # Test

# %%
test_dataset = VLMQADataset(dataset["test"], is_train=False)

# %%
from tqdm import tqdm

test_results = []

for index in tqdm(range(0, len(dataset["test"]), 10), desc="Generating predictions"):
    sample = dataset["test"][index]

    output = peft_model.generate(
        **test_dataset[index].to("cuda", dtype=torch.bfloat16),
        max_new_tokens=32
    )
    generated_texts = processor.batch_decode(output, skip_special_tokens=True)
    pred = generated_texts[0].split("Assistant: ")[-1]

    test_results.append({
        "scene_description": sample["scene_description"],
        "nuscenes_index": sample["nuscenes_index"],
        "task": sample["task"],
        "question": sample["question"],
        "answer": sample["answer"],
        "prediction": pred
    })

# %%
from huggingface_hub import login

login(token="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")

# %%
from datasets import Dataset

hf_dataset = Dataset.from_list(test_results)
hf_dataset.push_to_hub(
    "MehdiJmlkh/SmolVLM-FT-Results",
    private=False,
    commit_message="Save results"
)
